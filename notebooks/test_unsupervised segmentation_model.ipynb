# %%
import os
import glob

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/kanezaki/pytorch-unsupervised-segmentation-tip.git
# Out:
# Cloning into 'pytorch-unsupervised-segmentation-tip'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 68 (delta 13), reused 59 (delta 7), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
# run the demo
os.chdir('/content/pytorch-unsupervised-segmentation-tip')
# !python demo.py --visualize 0 --input ./BSD500/101027.jpg
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# 0 / 1000 |  label num : 100  | loss : 3.9792323112487793
# 1 / 1000 |  label num : 100  | loss : 3.509972095489502
# 2 / 1000 |  label num : 94  | loss : 3.2180466651916504
# 3 / 1000 |  label num : 83  | loss : 2.9820892810821533
# 4 / 1000 |  label num : 73  | loss : 2.7814786434173584
# 5 / 1000 |  label num : 65  | loss : 2.615708827972412
# 6 / 1000 |  label num : 61  | loss : 2.5403151512145996
# 7 / 1000 |  label num : 57  | loss : 2.314133644104004
# 8 / 1000 |  label num : 46  | loss : 2.153700351715088
# 9 / 1000 |  label num : 36  | loss : 1.9425581693649292
# 10 / 1000 |  label num : 34  | loss : 1.7565628290176392
# 11 / 1000 |  label num : 30  | loss : 1.571466088294983
# 12 / 1000 |  label num : 29  | loss : 1.4249346256256104
# ...

# %%
# !ls
# Out:
# BBC	demo.py      LICENSE	 PASCAL_VOC_2012
# BSD500	demo_ref.py  output.png  README.md

# %%
from IPython.display import Image
Image('output.png')

# %%
os.mkdir('/content/coral')
os.chdir('/content/coral')
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-044d4885315e> in <module>()
# ----> 1 os.mkdir('/content/coral')
#       2 os.chdir('/content/coral')
#       3 get_ipython().system('ls')
#
# FileExistsError: [Errno 17] File exists: '/content/coral'

# %%
# copy a coral photograph locally to try the algorithm
# !cp "/content/gdrive/MyDrive/Reef Support Benthic Data/SEAVIEW/PAC_SLB/34002091102.jpg" .

# %%
# !ls
# Out:
# 34002091102.jpg

# %%
# !python /content/pytorch-unsupervised-segmentation-tip/demo.py --visualize 0 --input 34002091102.jpg
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# 0 / 1000 |  label num : 100  | loss : 3.9879839420318604
# 1 / 1000 |  label num : 99  | loss : 3.6926393508911133
# 2 / 1000 |  label num : 97  | loss : 3.504976749420166
# 3 / 1000 |  label num : 94  | loss : 3.3900327682495117
# 4 / 1000 |  label num : 91  | loss : 3.2931668758392334
# 5 / 1000 |  label num : 86  | loss : 3.172992706298828
# 6 / 1000 |  label num : 63  | loss : 3.0260238647460938
# 7 / 1000 |  label num : 63  | loss : 2.9184377193450928
# 8 / 1000 |  label num : 50  | loss : 2.7494912147521973
# 9 / 1000 |  label num : 42  | loss : 2.587036609649658
# 10 / 1000 |  label num : 35  | loss : 2.447751522064209
# 11 / 1000 |  label num : 31  | loss : 2.2927491664886475
# 12 / 1000 |  label num : 27  | loss : 2.0970630645751953
# ...

# %%
Image('output.png')

# %%
path_list = []

from pathlib import Path
for path in Path('.').rglob('*.jpg'):
  print(path.absolute)
  path_list.append(path)

# %%
print(path.absolute)

# %%
from IPython.display import Image

# %%
path_list[1]

# %%
Image(filename=path_list[1].absolute)
